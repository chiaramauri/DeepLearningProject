# %% [markdown]
# Implementation of the RNN with one-hot encoding of words.

# %%
import pickle
import numpy as np
import tensorflow as tf
from tensorflow.python.ops.nn import relu, softmax
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix 
from tensorflow.contrib.layers import batch_norm, dropout
from tensorflow.python.ops import nn_ops
from tensorflow.python.ops import math_ops

#import training, validation and test set

with open('train_sentences_id_balanced.pickle','rb') as file:
    training_sentences = pickle.load(file)
    
with open('train_labels_balanced.pickle','rb') as file:
    training_labels = pickle.load(file)
    
    
with open('valid_sentences_id_balanced.pickle','rb') as file:
    validation_sentences = pickle.load(file)
    
with open('valid_labels_balanced.pickle','rb') as file:
    validation_labels = pickle.load(file)
    

with open('test_sentences_id_balanced.pickle','rb') as file:
    test_sentences = pickle.load(file)
    
with open('test_labels_balanced.pickle','rb') as file:
    test_labels = pickle.load(file)
    
with open('test_word_sentences_balanced.pickle','rb') as file:
    test_word_sentences = pickle.load(file)

print(test_sentences[0][:])
print(test_word_sentences[0])
print(test_labels[0])
# Out:
# /Users/claire/anaconda3/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# [2363, 10141, 9107, 10, 4223, 5103, 3116, 10280]
# ['Finanseksperter vurderer at de kan tjene 100% af den investering, de laver, på få år.']
# 1.0

# %%
def init_list_of_objects(size):
    list_of_objects = list()
    for i in range(0,size):
        list_of_objects.append( list() ) #different object reference each time
    return list_of_objects

# %%
#information about the dataset

num_training=len(training_sentences)
num_valid=len(validation_sentences)
num_test=len(test_sentences)
num_words=max(max(max(training_sentences)),max(max(validation_sentences)),max(max(test_sentences)))
num_claims_train=sum(training_labels)
num_claims_valid=sum(validation_labels)
num_claims_test=sum(test_labels)

print('total number of sentences:',num_training+num_valid+num_test)
print('number of training exemples:',num_training)
print('number of validation exemples:',num_valid)
print('number of test exemples:',num_test)
print('total number of words:',num_words)
print('Total number of claims: ', num_claims_train+num_claims_valid+num_claims_test)
print('Number of claims in the training set: ', num_claims_train)
print('Number of claims in the validation set: ', num_claims_valid)
print('Number of claims in the test set: ', num_claims_test)


max_input_len_train = max([len(list(i)) for i in training_sentences])
max_input_len_valid = max([len(list(i)) for i in validation_sentences])
max_input_len_test = max([len(list(i)) for i in test_sentences])
max_input_len=max(max_input_len_train,max_input_len_valid,max_input_len_test)
print('maximum input length:',max_input_len)

#zero padding on input

seq_len_train = []
train_exemples = np.zeros((num_training, max_input_len))
for (i,inp) in enumerate(training_sentences):
        cur_len = len(list(inp))
        train_exemples[i,:cur_len] = inp
        seq_len_train.append(cur_len)
seq_len_train=np.asarray(seq_len_train)

seq_len_valid = []
valid_exemples = np.zeros((num_valid, max_input_len))
for (i,inp) in enumerate(validation_sentences):
        cur_len = len(list(inp))
        valid_exemples[i,:cur_len] = inp
        seq_len_valid.append(cur_len)
seq_len_valid=np.asarray(seq_len_valid)

test_seq_len = []
test_exemples = np.zeros((num_test, max_input_len))
for (i,inp) in enumerate(test_sentences):
        cur_len = len(list(inp))
        test_exemples[i,:cur_len] = inp
        test_seq_len.append(cur_len)
test_seq_len=np.asarray(test_seq_len)
# Out:
# total number of sentences: 13578
# number of training exemples: 8149
# number of validation exemples: 2629
# number of test exemples: 2800
# total number of words: 10391
# Total number of claims:  5680.0
# Number of claims in the training set:  3410.0
# Number of claims in the validation set:  1040.0
# Number of claims in the test set:  1230.0
# maximum input length: 41

# %%
dim_output_network=2

print('training exemples shape: ', train_exemples.shape)
print('network output dimension:',dim_output_network)
# Out:
# training exemples shape:  (8149, 41)
# network output dimension: 2

# %%
def get_batch(batch_size=32, random=False, k=0):
    
    if random==True:
        indexes=np.random.choice(np.arange(num_training), (batch_size,), False)
        batch_exemples = train_exemples[indexes,:]
        batch_labels = training_labels[indexes]
        length = seq_len_train[indexes]
        return batch_exemples, batch_labels, length

    
    else:
        if (k+batch_size<num_training or k+batch_size==num_training):
            batch_exemples = train_exemples[k:batch_size+k,:]
            batch_labels = training_labels[k:batch_size+k]
            length = seq_len_train[k:batch_size+k]
            #mask=targets_mask[k:batch_size+k,:]
            index=k+batch_size
        else:
            batch_exemples = np.concatenate((train_exemples[k:num_training,:],\
                                             train_exemples[0:batch_size-(num_training-k),:]),axis=0) 
            batch_labels = np.concatenate((training_labels[k:num_training],\
                                           training_labels[0:batch_size-(num_training-k)]),axis=0) 
            length = np.concatenate((seq_len_train[k:num_training],seq_len_train[0:batch_size-(num_training-k)]),axis=0)
            
            index=batch_size-(num_training-k)
        
        return batch_exemples, batch_labels, length, index

# %%
# resetting the graph
tf.reset_default_graph()

# Setting up hyperparameters and general configs
NUM_INPUTS = num_words 
NUM_OUTPUTS = dim_output_network 
BATCH_SIZE = 32
LEARNING_RATE = 0.0001
NUM_UNITS_ENC = 3


# Setting up placeholders

# Data input
x_pl = tf.placeholder(tf.int32, shape=[None, None], name='X_input')
# Binary labels
y_pl = tf.placeholder(tf.int32, shape=[None, ], name='output')
# Length of the input sequence i.e. number of words
x_len = tf.placeholder(tf.int32, shape=[None], name='X_len')
#positive class threshold
threshold_pl=tf.placeholder(tf.float32, shape=[], name='threshold')

print('x_pl shape:',x_pl.shape)
print('y_pl shape:',y_pl.shape)
print('x_len shape:',x_len.shape)
print('threshold_pl shape:',threshold_pl.shape)

### Building the model

X_embeddings=tf.eye(num_words+1)
X_embedded = tf.gather(X_embeddings, x_pl, name='embed_X')
enc_cell = tf.nn.rnn_cell.GRUCell(NUM_UNITS_ENC)
_, enc_state = tf.nn.dynamic_rnn(cell=enc_cell, inputs=X_embedded, sequence_length=x_len, dtype=tf.float32)

# setting up weights for computing the final output
W_out = tf.get_variable('W_out', [NUM_UNITS_ENC, NUM_OUTPUTS])
b_out = tf.get_variable('b_out', [NUM_OUTPUTS])

# computing output
y = tf.nn.softmax(tf.matmul(enc_state, W_out) + b_out, name='l_out')
# Out:
# x_pl shape: (?, ?)
# y_pl shape: (?,)
# x_len shape: (?,)
# threshold_pl shape: ()

# %%
def sequence_loss_tensor(logits, targets,
                         average_across_timesteps=True,
                         softmax_loss_function=None, name=None):
    """cross-entropy loss for a sequence of logits (per example).
    """
    
    name = "sequenceLoss" if name is None else name
    with tf.variable_scope(name):
    
        if softmax_loss_function is None:
            crossent = nn_ops.sparse_softmax_cross_entropy_with_logits(
                    logits=logits, labels=targets)
        else:
            crossent = softmax_loss_function(logits, targets)
        
        crossent = tf.reduce_mean(crossent)


        return crossent

# %%
# 1) Define cross entropy loss
with tf.variable_scope('loss'):
    loss=tf.get_variable('loss',[])
    loss = sequence_loss_tensor(y, y_pl) #compute cross entropy
    # regularization
    reg_scale = 0.0001
    regularize = tf.contrib.layers.l1_regularizer(reg_scale)
    params = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES)
    reg_term = sum([regularize(param) for param in params])
    loss += reg_term

# 2) Define the training op
with tf.variable_scope('trainOP'):
    optimizer = tf.train.AdamOptimizer(learning_rate=LEARNING_RATE)  
    # use global step to keep track of our iterations
    global_step = tf.Variable(0, name='global_step', trainable=False)
    grads_and_vars = optimizer.compute_gradients(loss)
    train_op = optimizer.apply_gradients(grads_and_vars, global_step=global_step)

with tf.variable_scope('performance'):
    
        binary_pred=tf.greater(y[:,1], threshold_pl)
        binary_pred=tf.cast(binary_pred,tf.int32, name='predictions')
        # making a one-hot encoded vector of correct (1) and incorrect (0) prediction
        correct_prediction = tf.equal(binary_pred, y_pl)
        # averaging the one-hot encoded vecto
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name='accuracy')
        _, auc_op = tf.contrib.metrics.streaming_auc(predictions=y[:,1], labels=y_pl, num_thresholds=300, name='auc')
        _, sensitivity_op= tf.metrics.recall(labels=y_pl, predictions=binary_pred, name='sensitivity')
        conf_matrix = tf.confusion_matrix(labels=y_pl, predictions=binary_pred, num_classes=2)
        specificity = tf.divide(conf_matrix[0,0], conf_matrix[0,0] + conf_matrix[0,1], name='specificity')

# %%
gpu_opts = tf.GPUOptions(per_process_gpu_memory_fraction=0.35)
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_opts))
sess.run(tf.global_variables_initializer())

# %%
#Test the forward pass
batch_size = 32

# Get a mini-batch
x_batch=train_exemples[0:batch_size,:]
print('x_batch shape:',np.shape(x_batch))
y_batch=training_labels[0:batch_size]
print('y_batch shape:',np.shape(y_batch))
x_length=seq_len_train[0:batch_size]
feed_dict = {x_pl: x_batch, x_len: x_length, y_pl: y_batch}

# test training forwardpass
fetches = [y]
res = sess.run(fetches=fetches, feed_dict=feed_dict)
print("y", res[0].shape)
# Out:
# x_batch shape: (32, 41)
# y_batch shape: (32,)
# y (32, 2)

# %%
#Training Loop


# setting up running parameters
val_interval = 150
batches_to_process = 6.5e3
batches_processed = 0
threshold=0.35
index=0
batches_valid= []
val_loss, val_acc, val_auc, val_sens, val_spec = [], [], [], [], []
train_loss, train_acc, train_auc, train_sens, train_spec = [], [], [], [], []
val_num=0


print('Begin training loop')
try:
    while batches_processed < batches_to_process:
        # load data
        x_tr, y_tr, x_len_tr, index = get_batch(batch_size=BATCH_SIZE, random=False, k=index)
        # make fetches
        fetches_tr = [train_op, loss, accuracy, auc_op, sensitivity_op, specificity]
         #set up feed dict
        feed_dict_tr = {x_pl: x_tr, x_len: x_len_tr, y_pl: y_tr, threshold_pl : threshold}
        # run the model
        sess.run(tf.local_variables_initializer())
        res = tuple(sess.run(fetches=fetches_tr, feed_dict=feed_dict_tr))
        _, batch_loss, batch_acc, batch_auc, batch_sens, batch_spec = res
        batches_processed += 1
        
        if batches_processed % val_interval == 0:
            train_loss += [batch_loss]
            train_acc += [batch_acc]
            train_auc += [batch_auc]
            train_sens += [batch_sens]
            train_spec += [batch_spec]
            print("Batch number {}: Train Loss {:6.3f},  Train Acc {:6.3f}, Train AUC {:6.3f}, Train Sensitivity {:6.3f}, Train Specificity {:6.3f}".format(
                batches_processed, train_loss[-1], train_acc[-1], train_auc[-1], train_sens[-1], train_spec[-1] ))
            
            #validation 
            val_num=val_num+1
            fetches_valid = [loss, accuracy, auc_op, sensitivity_op, specificity]
            feed_dict_valid = {x_pl: valid_exemples, x_len: seq_len_valid, y_pl: validation_labels, threshold_pl : threshold}
            sess.run(tf.local_variables_initializer())
            _loss, _acc, _auc, _sens, _spec = sess.run(fetches_valid, feed_dict_valid)
            val_acc += [_acc]
            val_loss += [_loss]
            val_auc+= [_auc]
            val_sens+= [_sens]
            val_spec+= [_spec]
            batches_valid += [batches_processed]
            print("Validation number {}: Val Loss {:6.3f},  Val Acc {:6.3f}, Val AUC {:6.3f}, Val Sensitivity {:6.3f}, Val Specificity {:6.3f}".format(
                    val_num, val_loss[-1], val_acc[-1], val_auc[-1], val_sens[-1], val_spec[-1]))
            
    #test
    feed_dict_test = {x_pl: test_exemples, x_len: test_seq_len, y_pl: test_labels, threshold_pl : threshold}
    fetches_test = [loss, accuracy, auc_op, sensitivity_op, specificity, binary_pred, y]
    sess.run(tf.local_variables_initializer())
    test_loss, test_acc, test_auc, test_sens, test_spec, test_pred, test_prob = sess.run(fetches_test, feed_dict_test)
    
    fpr_test, tpr_test, _ = roc_curve(test_labels, test_prob[:,1])
    roc_auc_test = auc(fpr_test, tpr_test)
    TN, FP, FN, TP = confusion_matrix(test_labels, test_pred).ravel()

    test_accuracy=(TN+TP)/float(TN+FP+FN+TP) #prop di risposte corrette in tot
    test_sensitivity = TP / float(FN + TP) #veri p
    test_specificity = TN / (TN + FP) #
    print('Test Loss {:6.3f}, Test Acc {:6.3f}, Test AUC {:6.3f}, Test Sensitivity {:6.3f}, Test Specificity {:6.3f}'.format(
                    test_loss, test_acc, test_auc, test_sens, test_spec))
    print('Test Loss {:6.3f}, Test Acc {:6.3f}, Test AUC {:6.3f}, Test Sensitivity {:6.3f}, Test Specificity {:6.3f}'.format(
                    test_loss, test_accuracy, roc_auc_test, test_sensitivity, test_specificity))
except KeyboardInterrupt:
    pass

print('Done')
# Out:
# Begin training loop
# Batch number 150: Train Loss  0.704,  Train Acc  0.438, Train AUC  0.528, Train Sensitivity  1.000, Train Specificity  0.000
# Validation number 1: Val Loss  0.693,  Val Acc  0.396, Val AUC  0.508, Val Sensitivity  1.000, Val Specificity  0.000
# Batch number 300: Train Loss  0.679,  Train Acc  0.406, Train AUC  0.646, Train Sensitivity  1.000, Train Specificity  0.000
# Validation number 2: Val Loss  0.676,  Val Acc  0.396, Val AUC  0.558, Val Sensitivity  1.000, Val Specificity  0.000
# Batch number 450: Train Loss  0.696,  Train Acc  0.469, Train AUC  0.559, Train Sensitivity  1.000, Train Specificity  0.000
# Validation number 3: Val Loss  0.676,  Val Acc  0.396, Val AUC  0.526, Val Sensitivity  1.000, Val Specificity  0.000
# Batch number 600: Train Loss  0.661,  Train Acc  0.344, Train AUC  0.483, Train Sensitivity  1.000, Train Specificity  0.000
# Validation number 4: Val Loss  0.675,  Val Acc  0.396, Val AUC  0.547, Val Sensitivity  1.000, Val Specificity  0.000
# Batch number 750: Train Loss  0.651,  Train Acc  0.312, Train AUC  0.691, Train Sensitivity  1.000, Train Specificity  0.000
# Validation number 5: Val Loss  0.675,  Val Acc  0.396, Val AUC  0.596, Val Sensitivity  1.000, Val Specificity  0.000
# Batch number 900: Train Loss  0.677,  Train Acc  0.406, Train AUC  0.844, Train Sensitivity  1.000, Train Specificity  0.000
# Validation number 6: Val Loss  0.675,  Val Acc  0.396, Val AUC  0.585, Val Sensitivity  1.000, Val Specificity  0.000
# Batch number 1050: Train Loss  0.678,  Train Acc  0.406, Train AUC  0.670, Train Sensitivity  1.000, Train Specificity  0.000
# Validation number 7: Val Loss  0.675,  Val Acc  0.396, Val AUC  0.570, Val Sensitivity  1.000, Val Specificity  0.000
# Batch number 1200: Train Loss  0.660,  Train Acc  0.344, Train AUC  0.740, Train Sensitivity  1.000, Train Specificity  0.000
# Validation number 8: Val Loss  0.675,  Val Acc  0.394, Val AUC  0.616, Val Sensitivity  0.990, Val Specificity  0.004
# Batch number 1350: Train Loss  0.686,  Train Acc  0.438, Train AUC  0.774, Train Sensitivity  1.000, Train Specificity  0.000
# Validation number 9: Val Loss  0.675,  Val Acc  0.402, Val AUC  0.623, Val Sensitivity  0.990, Val Specificity  0.018
# Batch number 1500: Train Loss  0.659,  Train Acc  0.375, Train AUC  0.721, Train Sensitivity  1.000, Train Specificity  0.048
# Validation number 10: Val Loss  0.675,  Val Acc  0.409, Val AUC  0.605, Val Sensitivity  0.981, Val Specificity  0.035
# Batch number 1650: Train Loss  0.658,  Train Acc  0.344, Train AUC  0.779, Train Sensitivity  1.000, Train Specificity  0.000
# Validation number 11: Val Loss  0.675,  Val Acc  0.423, Val AUC  0.611, Val Sensitivity  0.952, Val Specificity  0.077
# Batch number 1800: Train Loss  0.632,  Train Acc  0.281, Train AUC  0.784, Train Sensitivity  1.000, Train Specificity  0.042
# Validation number 12: Val Loss  0.675,  Val Acc  0.435, Val AUC  0.627, Val Sensitivity  0.933, Val Specificity  0.109
# Batch number 1950: Train Loss  0.693,  Train Acc  0.625, Train AUC  0.857, Train Sensitivity  1.000, Train Specificity  0.294
# Validation number 13: Val Loss  0.674,  Val Acc  0.463, Val AUC  0.632, Val Sensitivity  0.875, Val Specificity  0.193
# Batch number 2100: Train Loss  0.631,  Train Acc  0.438, Train AUC  0.820, Train Sensitivity  1.000, Train Specificity  0.250
# Validation number 14: Val Loss  0.674,  Val Acc  0.474, Val AUC  0.629, Val Sensitivity  0.865, Val Specificity  0.217
# Batch number 2250: Train Loss  0.649,  Train Acc  0.500, Train AUC  0.882, Train Sensitivity  1.000, Train Specificity  0.273
# Validation number 15: Val Loss  0.674,  Val Acc  0.489, Val AUC  0.636, Val Sensitivity  0.817, Val Specificity  0.274
# Batch number 2400: Train Loss  0.683,  Train Acc  0.562, Train AUC  0.909, Train Sensitivity  1.000, Train Specificity  0.222
# Validation number 16: Val Loss  0.674,  Val Acc  0.494, Val AUC  0.644, Val Sensitivity  0.779, Val Specificity  0.308
# Batch number 2550: Train Loss  0.702,  Train Acc  0.688, Train AUC  0.873, Train Sensitivity  1.000, Train Specificity  0.375
# Validation number 17: Val Loss  0.674,  Val Acc  0.499, Val AUC  0.644, Val Sensitivity  0.769, Val Specificity  0.322
# Batch number 2700: Train Loss  0.692,  Train Acc  0.594, Train AUC  0.810, Train Sensitivity  0.800, Train Specificity  0.412
# Validation number 18: Val Loss  0.674,  Val Acc  0.515, Val AUC  0.647, Val Sensitivity  0.769, Val Specificity  0.349
# Batch number 2850: Train Loss  0.668,  Train Acc  0.500, Train AUC  0.615, Train Sensitivity  0.750, Train Specificity  0.350
# Validation number 19: Val Loss  0.674,  Val Acc  0.514, Val AUC  0.654, Val Sensitivity  0.788, Val Specificity  0.335
# Batch number 3000: Train Loss  0.647,  Train Acc  0.625, Train AUC  0.900, Train Sensitivity  0.900, Train Specificity  0.500
# Validation number 20: Val Loss  0.674,  Val Acc  0.531, Val AUC  0.650, Val Sensitivity  0.769, Val Specificity  0.375
# Batch number 3150: Train Loss  0.692,  Train Acc  0.469, Train AUC  0.761, Train Sensitivity  0.867, Train Specificity  0.118
# Validation number 21: Val Loss  0.673,  Val Acc  0.524, Val AUC  0.656, Val Sensitivity  0.788, Val Specificity  0.351
# Batch number 3300: Train Loss  0.663,  Train Acc  0.594, Train AUC  0.858, Train Sensitivity  0.917, Train Specificity  0.400
# Validation number 22: Val Loss  0.673,  Val Acc  0.519, Val AUC  0.666, Val Sensitivity  0.798, Val Specificity  0.336
# Batch number 3450: Train Loss  0.726,  Train Acc  0.719, Train AUC  0.902, Train Sensitivity  0.950, Train Specificity  0.333
# Validation number 23: Val Loss  0.673,  Val Acc  0.509, Val AUC  0.668, Val Sensitivity  0.817, Val Specificity  0.307
# Batch number 3600: Train Loss  0.684,  Train Acc  0.625, Train AUC  0.886, Train Sensitivity  1.000, Train Specificity  0.294
# Validation number 24: Val Loss  0.673,  Val Acc  0.510, Val AUC  0.671, Val Sensitivity  0.837, Val Specificity  0.297
# Batch number 3750: Train Loss  0.659,  Train Acc  0.594, Train AUC  0.877, Train Sensitivity  1.000, Train Specificity  0.350
# Validation number 25: Val Loss  0.672,  Val Acc  0.523, Val AUC  0.678, Val Sensitivity  0.827, Val Specificity  0.324
# Batch number 3900: Train Loss  0.678,  Train Acc  0.562, Train AUC  0.780, Train Sensitivity  0.929, Train Specificity  0.278
# Validation number 26: Val Loss  0.671,  Val Acc  0.525, Val AUC  0.683, Val Sensitivity  0.846, Val Specificity  0.314
# Batch number 4050: Train Loss  0.652,  Train Acc  0.562, Train AUC  0.860, Train Sensitivity  0.917, Train Specificity  0.350
# Validation number 27: Val Loss  0.670,  Val Acc  0.519, Val AUC  0.689, Val Sensitivity  0.865, Val Specificity  0.292
# Batch number 4200: Train Loss  0.693,  Train Acc  0.625, Train AUC  0.886, Train Sensitivity  0.941, Train Specificity  0.267
# Validation number 28: Val Loss  0.669,  Val Acc  0.522, Val AUC  0.696, Val Sensitivity  0.865, Val Specificity  0.297
# Batch number 4350: Train Loss  0.647,  Train Acc  0.562, Train AUC  0.898, Train Sensitivity  1.000, Train Specificity  0.300
# Validation number 29: Val Loss  0.667,  Val Acc  0.523, Val AUC  0.706, Val Sensitivity  0.865, Val Specificity  0.300
# Batch number 4500: Train Loss  0.658,  Train Acc  0.656, Train AUC  0.904, Train Sensitivity  1.000, Train Specificity  0.353
# Validation number 30: Val Loss  0.665,  Val Acc  0.555, Val AUC  0.712, Val Sensitivity  0.856, Val Specificity  0.358
# Batch number 4650: Train Loss  0.677,  Train Acc  0.500, Train AUC  0.702, Train Sensitivity  0.929, Train Specificity  0.167
# Validation number 31: Val Loss  0.662,  Val Acc  0.566, Val AUC  0.718, Val Sensitivity  0.856, Val Specificity  0.376
# Batch number 4800: Train Loss  0.666,  Train Acc  0.781, Train AUC  0.855, Train Sensitivity  1.000, Train Specificity  0.500
# Validation number 32: Val Loss  0.658,  Val Acc  0.579, Val AUC  0.724, Val Sensitivity  0.827, Val Specificity  0.417
# Batch number 4950: Train Loss  0.636,  Train Acc  0.562, Train AUC  0.820, Train Sensitivity  1.000, Train Specificity  0.333
# Validation number 33: Val Loss  0.653,  Val Acc  0.612, Val AUC  0.727, Val Sensitivity  0.808, Val Specificity  0.483
# Batch number 5100: Train Loss  0.614,  Train Acc  0.750, Train AUC  0.858, Train Sensitivity  0.917, Train Specificity  0.650
# Validation number 34: Val Loss  0.649,  Val Acc  0.633, Val AUC  0.726, Val Sensitivity  0.779, Val Specificity  0.537
# Batch number 5250: Train Loss  0.576,  Train Acc  0.750, Train AUC  0.944, Train Sensitivity  1.000, Train Specificity  0.619
# Validation number 35: Val Loss  0.646,  Val Acc  0.660, Val AUC  0.717, Val Sensitivity  0.740, Val Specificity  0.607
# Batch number 5400: Train Loss  0.572,  Train Acc  0.656, Train AUC  0.939, Train Sensitivity  0.909, Train Specificity  0.524
# Validation number 36: Val Loss  0.644,  Val Acc  0.661, Val AUC  0.711, Val Sensitivity  0.702, Val Specificity  0.634
# Batch number 5550: Train Loss  0.634,  Train Acc  0.781, Train AUC  0.898, Train Sensitivity  0.812, Train Specificity  0.750
# Validation number 37: Val Loss  0.642,  Val Acc  0.674, Val AUC  0.706, Val Sensitivity  0.654, Val Specificity  0.688
# Batch number 5700: Train Loss  0.608,  Train Acc  0.844, Train AUC  0.880, Train Sensitivity  0.824, Train Specificity  0.867
# Validation number 38: Val Loss  0.641,  Val Acc  0.686, Val AUC  0.700, Val Sensitivity  0.625, Val Specificity  0.726
# Batch number 5850: Train Loss  0.482,  Train Acc  0.969, Train AUC  0.996, Train Sensitivity  1.000, Train Specificity  0.952
# Validation number 39: Val Loss  0.640,  Val Acc  0.692, Val AUC  0.693, Val Sensitivity  0.596, Val Specificity  0.755
# Batch number 6000: Train Loss  0.587,  Train Acc  0.812, Train AUC  0.862, Train Sensitivity  0.889, Train Specificity  0.783
# Validation number 40: Val Loss  0.640,  Val Acc  0.697, Val AUC  0.689, Val Sensitivity  0.587, Val Specificity  0.769
# Batch number 6150: Train Loss  0.483,  Train Acc  0.906, Train AUC  0.950, Train Sensitivity  0.900, Train Specificity  0.909
# Validation number 41: Val Loss  0.640,  Val Acc  0.698, Val AUC  0.681, Val Sensitivity  0.548, Val Specificity  0.795
# Batch number 6300: Train Loss  0.533,  Train Acc  0.875, Train AUC  0.915, Train Sensitivity  0.889, Train Specificity  0.870
# Validation number 42: Val Loss  0.639,  Val Acc  0.692, Val AUC  0.676, Val Sensitivity  0.519, Val Specificity  0.805
# Batch number 6450: Train Loss  0.482,  Train Acc  0.938, Train AUC  0.942, Train Sensitivity  0.929, Train Specificity  0.944
# Validation number 43: Val Loss  0.640,  Val Acc  0.696, Val AUC  0.669, Val Sensitivity  0.510, Val Specificity  0.817
# Test Loss  0.660, Test Acc  0.665, Test AUC  0.680, Test Sensitivity  0.496, Test Specificity  0.797
# Test Loss  0.660, Test Acc  0.665, Test AUC  0.680, Test Sensitivity  0.496, Test Specificity  0.797
# Done

# %%
#plot learning curves

fig=plt.figure()
fig.add_subplot()
plt.plot(batches_valid, train_loss, 'r-', label='Train Loss')
plt.plot(batches_valid, val_loss, 'b-', label='Valid Loss')
plt.legend()
plt.ylabel('Loss', fontsize=15)
plt.xlabel('Processed batches', fontsize=15)
plt.title('Loss', fontsize=20)
plt.grid('on')
plt.tight_layout()
plt.show()    
            
fig.add_subplot()
plt.plot(batches_valid, train_acc, 'r-', label='Train Acc')
plt.plot(batches_valid, val_acc, 'b-', label='Valid Acc')
plt.legend()
plt.ylabel('Accuracy', fontsize=15)
plt.xlabel('Processed batches', fontsize=15)
plt.title('Accuracy', fontsize=20)
plt.grid('on')
plt.tight_layout()
plt.show()       


fig=plt.figure()
fig.add_subplot()
plt.plot(batches_valid, train_sens, 'r-', label='Train Sensitivity')
plt.plot(batches_valid, val_sens, 'b-', label='Valid Sensitivity')
plt.legend()
plt.ylabel('Sensitivity', fontsize=15)
plt.xlabel('Processed batches', fontsize=15)
plt.title('Sensitivity', fontsize=20)
plt.grid('on')
plt.tight_layout()
plt.show()   

fig.add_subplot()
plt.plot(batches_valid, train_spec, 'r-', label='Train Specificity')
plt.plot(batches_valid, val_spec, 'b-', label='Valid Specificity')
plt.legend()
plt.ylabel('Specificity', fontsize=15)
plt.xlabel('Processed batches', fontsize=15)
plt.title('Specificity', fontsize=20)
plt.grid('on') 
plt.tight_layout()
plt.show()   

plt.figure()
plt.plot(batches_valid, train_auc, 'r-', label='Train AUC')
plt.plot(batches_valid, val_auc, 'b-', label='Valid AUC')
plt.legend()
plt.legend()
plt.ylabel('AUC', fontsize=15)
plt.xlabel('Processed batches', fontsize=15)
plt.title('AUC', fontsize=20)
plt.grid('on')
plt.tight_layout()
plt.show()  

plt.figure()
plt.plot(fpr_test, tpr_test, color='darkorange', label='ROC curve (area = %0.2f)' % test_auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=15)
plt.ylabel('True Positive Rate', fontsize=15)
plt.title('Receiver operating characteristic', fontsize=20)
plt.legend(loc="lower right")
plt.tight_layout()
plt.show()

# %%
## Save model

saver = tf.train.Saver()
saver.save(sess, "./rnn_onehot_3units_2")
# Out:
# './rnn_onehot_3units_2'

# %%
#see some exemples

unique_test_sentences = [] 
unique_test_labels = []
unique_test_pred = []


for (i,sent) in enumerate(test_word_sentences):
    if sent not in unique_test_sentences:
        #print(sent)
        unique_test_sentences.append(sent)
        unique_test_labels.append(test_labels[i])
        unique_test_pred.append(test_pred[i])
        
true_pos = []
false_pos = []
true_neg = []
false_neg = []

print('Number of test sentences: ',len(test_word_sentences))
print('Number of unique test sentences: ',len(unique_test_sentences))

for (i,pred) in enumerate(unique_test_pred):
    if(pred==1):
        if (unique_test_labels[i]==1):
            true_pos.append(unique_test_sentences[i])
        else:
             false_pos.append(unique_test_sentences[i])
    else:
        if (unique_test_labels[i]==1):
            false_neg.append(unique_test_sentences[i])
        else:
             true_neg.append(unique_test_sentences[i])
    
print('\nTrue positives: ')
for i in np.arange(min(10,len(true_pos))):
    print(true_pos[i])
print('\nFalse positives: ')
for i in np.arange(min(10,len(false_pos))):
    print(false_pos[i])
print('\nTrue negatives: ')
for i in np.arange(min(10,len(true_neg))):
    print(true_neg[i])
print('\nFalse negatives: ')
for i in np.arange(min(10,len(false_neg))):
    print(false_neg[i])
# Out:
# Number of test sentences:  2800
# Number of unique test sentences:  1689
#
# True positives:
# ['Finanseksperter vurderer at de kan tjene 100% af den investering, de laver, på få år.']
# ['Danmark står i en unik situation, fordi vi er et førerland.']
# ['Alternative diæter er tidens store sundhedstrend og mange familier følger den nyeste kostreligion.']
# ['Der er investeret næsten 500 mio. kr. over de første år blandt 3700 indbyggere. Det er rigtig mange penge per indbygger.']
# ['Vi smed astmasprayene ud, havde ikke forstoppelse mere eller bylder, bumser og eksem. Jeg tænkte: Hvad sker der?']
# ['De vil til næste år beløbe sig til 42 mia. kr.']
# ['Jo, den gør. Vi støtter massivt i forhold til fossile brændstoffer blandt andet i landbruget, med 1,5 milliard om året, til diesel.']
# ['I 9 og 10 stiger det 15 procent. Vi har fremrykket trafikinvesteringer.']
# ['Over en tiårig periode faldt vandforbruget i Danmark.']
# ['I Tyskland har man så 80-90 millioner stemmer og i Danmark har man 5 millioner. Det er den udvikling, der er i gang.']
#
# False positives:
# ['Jeg har hørt det så mange gange. Så der kommer stærke krav om at vi må i frugtbar dialog med mennesker af anden etnisk herkomst.']
# ['Veronika Schultz, formand for de danske gymnasieelever.']
# ['For det første har det kun været en erhvervspolitik i to et halvt år. Fik vi vindmøller for to år siden? Nej, nej.']
# ['Den har fået masser af mennesker i arbejde.']
# ['Vi har snakket om Goldman Sachs. Nu diskuterer vi EU.']
# ['Er folkeskolen og institutionerne underlagt for mange mål? Nu skal du sige ja. Det kan jeg høre.']
# ['Forslaget går dermed længere end forslaget fra sidste år.']
# ['Han er faktisk blevet en utrolig populær premierminister.']
# ['Sektoren har selv spillet ud med at stramme op på nogle elementer. Men det er åbenbart ikke nok. Du kan ikke hindre krisen nu.']
# ['på kloakker og skoler end det, regeringen allerede gør. Det er jo komplet uansvarligt.']
#
# True negatives:
# ['god regeringsførelse og udvikling. Og nøglen er de afghanske tropper? Ja.']
# ['Vi skal kunne tage en seriøs debat om bekymringen hos befolkningen.']
# ['Hos os var det et statussymbol, at maden gik rundt tre gange og der var sovs nok på kartoflerne.']
# ['I regeringen er man uenige på meget fundamentale områder.']
# ['Da jeg var ung og med i antiapartheid og syntes, det var forfærdeligt ...']
# ['Det gør det svært at have tillid til, at borgerne får ordentlig oplysning.']
# ['Den frie bevægelighed er en af grundpillerne i EU.']
# ['Det her udspringer eventuelt af nogle kulturelle normer.']
# ['Jeg tænker på politikken: Du er din egen lykkes smed. Jeg mener vi glemmer muligheden, der er i at lave påbud og forbud afløftning af moms på sunde varer der gør, at det sunde er mere tilgængeligt.']
# ['Det kan højne det faglige niveau. Det er et svigt, at vi har fejlet dér.']
#
# False negatives:
# ['I dag tildeler man førtidspension til langt færre, end man gjorde før.']
# ['Man kunne få alle fordelene. Der var ingen ulemper.']
# ['Uenigheden er dyb, når det gælder de her spørgsmål.']
# ['I 2012 sagde politikerne på vores vegne ja tak til Finanspagten der satte helt nye krav til landenes finanspolitik.']
# ['Virksomheder betaler ikke energiafgifter som andre forbrugere.']
# ['Dumpeprocenterne på de fag er steget fra 10% til 50%.']
# ['Domstolen siger, at nu kan man gifte sig med en illegal indvandrer og få familiesammenføring. Så bliver det mere attraktivt at søge og at komme herop og få offentlige ydelser.']
# ['I forhold til dem, der ikke kommer i gang med en uddannelse har det vist sig, at moderens rolle er ret afgørende.']
# ['De danske soldater er der, fordi de gerne vil have at vi herhjemme kan leve i fred.']
# ['De sidste mange årtier har politikerne været enige om at flere skulle have uddannelse. Mere uddannelse var af det gode.']
